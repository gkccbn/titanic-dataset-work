# %%
#GÖKÇE ÇOBAN- 191180029
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly
import seaborn as sns

# %%
#'path' can be added according to the computer where the code is run
path = "C:\\Users\\gokce\\Desktop\\ceng313_assignment_1\\CENG313 Assignment 1\\train.csv"

# %%
df_titanic=pd.read_csv (path) # I used variable named 'path' for train.csv

# %%
#QUESTION 1 - information that belongs to the first six passengers is shown below
df_titanic.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
#QUESTION 2- column titles
for attrb in df_titanic.columns:
    print(attrb)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
#QUESTION 3- the number of passengers is shown below
print("number of passenger" , len(df_titanic))
# Out:
# number of passenger 891

# %%
#QUESTION 4- missing values are in the dataset for the columns “Age”,“Cabin”
#and “Embarked”
df_cabin= pd.read_csv (path , usecols =[ 'Cabin']) 
df_embarked= pd.read_csv (path , usecols =[ 'Embarked'])
df_age= pd.read_csv (path , usecols =[ 'Age'])

# %%
#QUESTION 4 
df_age.isnull().sum().sum()
# Out:
# 177

# %%
#QUESTION 4 
df_cabin.isnull().sum().sum()
# Out:
# 687

# %%
#QUESTION 4 
df_embarked.isnull().sum().sum()
# Out:
# 2

# %%
#QUESTION 5 - percentage of passengers that embarked from each 
#port is shown below as a list (Southampton, Cherbourg, Queenstown).
new_df = df_titanic['Embarked'].value_counts()

# %%
#QUESTION 5 - most number of people embarked from Southampton and
#the least amount of people embarked from queenstown
new_df.plot(kind='pie', autopct="%1.1f%%")
plt.show()

# %%
#QUESTION 6 - number of passengers traveling for each class are shown below. 
#if we look at the bar chart we can see that ticket class 3 had the most 
#number of passengers.
pclass_df =df_titanic["Pclass"].value_counts()

# %%
#QUESTION 6 -
pclass_df.plot(kind='bar')
plt.show()

# %%
#QUESTION 7 a plot that shows the number of female passengers for each ticket class who 
#survived and who did not survive in bar chart below

fem_died_len=len(df_titanic.loc[(df_titanic['Survived']==0) & (df_titanic['Sex']=='female') & (df_titanic['Pclass']==1)].index)
fem_surv_len=len(df_titanic.loc[(df_titanic['Survived']==1)&(df_titanic['Sex']=='female') & (df_titanic['Pclass']==1)].index)
fem_died_len2=len(df_titanic.loc[(df_titanic['Survived']==0)&(df_titanic['Sex']=='female') & (df_titanic['Pclass']==2) ].index)
fem_surv_len2=len(df_titanic.loc[(df_titanic['Survived']==1)&(df_titanic['Sex']=='female') & (df_titanic['Pclass']==2)].index)
fem_died_len3=len(df_titanic.loc[(df_titanic['Survived']==0)&(df_titanic['Sex']=='female') & (df_titanic['Pclass']==3)].index)
fem_surv_len3=len(df_titanic.loc[(df_titanic['Survived']==1)&(df_titanic['Sex']=='female') & (df_titanic['Pclass']==3)].index)

chart1 = {"Survivor":['Survived','Died'], "size":[fem_surv_len, fem_died_len]}
chart2 = {"Survivor":['Survived','Died'], "size":[fem_surv_len2, fem_died_len2]}
chart3 = {"Survivor":['Survived','Died'], "size":[fem_surv_len3, fem_died_len3]}

df_chart1=pd.DataFrame(data=chart1)
df_chart2=pd.DataFrame(data=chart2)
df_chart3=pd.DataFrame(data=chart3)

ax=df_chart1.plot.bar(x='Survivor', y='size',color = 'orange', title="ticket class 1")
ax=df_chart2.plot.bar(x='Survivor', y='size',color = 'orange', title=" ticket class 2")
ax=df_chart3.plot.bar(x='Survivor', y='size', color = 'orange' , title="ticket class 3")

# %%
#QUESTION 8 these two boxplots show the key age statistics of female and male passengers 
#who survived and who did not survive.
male_sur=df_titanic[(df_titanic['Sex']=='male')]
female_sur=df_titanic[(df_titanic['Sex']=='female')]

male_sur.boxplot('Age', by ='Survived', color='green',fontsize=14, figsize=(10,10))
female_sur.boxplot('Age', by= 'Survived', color='green', fontsize=14,  figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='Survived'>

# %%
#QUESTION 9-10 - we calculate the total number of death passengers by gender
died_gender = (gender['Survived'].size() - survived_gender)
died_gender.name = '0'

# %%
#QUESTION 9-10 - how many people for each gender 
#have survived?
#we calculate the number of survivors by gender
gender = df_titanic.groupby('Sex')
survived_gender = gender['Survived'].sum()
survived_gender.name = '1'

# %%
# QUESTION 9-10 total female and male passenger
all_gender = gender['Survived'].size()
all_gender.name = 'all'

# %%
# QUESTION 9-10 - according to table, female gender has the most number of survivors
#and  female gender had a higher survival rate. this female survival rate may be due to ticket classes

fem_male_all = pd.concat([all_gender,survived_gender, died_gender], axis=1)
fem_male_all
# Out:
#         all    1    0
# Sex
# female  314  233   81
# male    577  109  468

# %%
# QUESTION 11- we create new dataframe for survived, age, sex, fare and pclass attributes
cor_df = df_titanic[['Survived', 'Age', 'Sex', 'Fare','Pclass']]

# %%
# QUESTION 11-  we creat a heatmap for correlation between the attributes of survival, age, sex, fare, 
#and ticket class.
sns.heatmap(data = cor)
# Out:
# <AxesSubplot:>

# %%
# QUESTION 12- We  calculate “Pearson” standard correlation coefficient with using 'method'
cor = cor_df.corr(method='pearson')
cor
# Out:
#           Survived       Age      Fare    Pclass
# Survived  1.000000 -0.077221  0.257307 -0.338481
# Age      -0.077221  1.000000  0.096067 -0.369226
# Fare      0.257307  0.096067  1.000000 -0.549500
# Pclass   -0.338481 -0.369226 -0.549500  1.000000

# %%
# QUESTION 12 A heatmap for pearson standard correlation coefficient.
#correlation coefficient beetween survived and Pclass is -0.34 which
#could either be interpreted as a “good” or “moderate” correlation and it is not strong or weak correlation. 
f,ax = plt.subplots()
sns.heatmap(cor_df.corr(),annot=True, ax = ax)
# Out:
# <AxesSubplot:>

# %%
#QUESTION 13- according to csv table, youngest person age is 0.42 and it is a baby
df_titanic['Age'][df_titanic['Age'].idxmin()]
# Out:
# 0.42

# %%
#QUESTION 14- average fare is shown below
df_titanic['Fare'].mean()
# Out:
# 32.2042079685746

# %%
#QUESTION 15  oldest passenger who survived is 80 years old. 
survived_pass = df_titanic[(df_titanic['Survived']==1)]['Age'].max()
survived_pass
# Out:
# 80.0

# %%
#QUESTION 16 - if we look at the table below.
#the oldest female passenger who survived is 63 years old
old_fem_sur= df_titanic[(df_titanic['Sex'] == 'female') & (df_titanic['Survived'] == 1)]['Age'].max()
old_fem_sur
# Out:
# 63.0

# %%
#QUESTION 17 There is a child under age of 10 traveling without their parents
age10_noparents = df_titanic[(df_titanic['Age'] < 10) & (df_titanic['Parch']==0)]
age10_noparents
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 777          778         1       3  Emanuel, Miss. Virginia Ethel  female
#
#      Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 777  5.0      0      0  364516  12.475   NaN        S

# %%
#QUESTION-18 Age distrubution of the female and male passengers who survived is shown below
male_survived= df_titanic[(df_titanic['Sex']=='male') & (df_titanic['Survived']==1)]['Age'].dropna()
female_survived= df_titanic[(df_titanic['Sex']=='female') & (df_titanic['Survived']==1)]['Age'].dropna()

# %%
#QUESTION-18 Age distrubution of the female and male passengers who survived is shown in the histogram below
#When we look at the yellow color, that is, the female gender, it is seen that female gender 
#have a higher chance of survival.
plt.hist(male_survived, label="male/survived", alpha=.4, color='red')
plt.hist(female_survived, label="female/survived", alpha=.4, color='yellow', edgecolor='darkblue')
plt.legend()
plt.show()

# %%
#QUESTION 19 - highest number of siblings is 8
df_titanic['SibSp'][df_titanic['SibSp'].idxmax()]
# Out:
# 8

# %%
#QUESTION 20- a scatterplot that shows the age–fare correlation for passengers who survived 
#and who did not survive is shown below
sns.lmplot('Age', y='Fare', hue='Survived', data=df_titanic)
# Out:
# C:\Users\gokce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
